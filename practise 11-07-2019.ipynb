# %%
f=open("txt.txt",'w')

# %%
f.write("hai how are you")
# Out:
# 15

# %%
f.close()

# %%
f1=open("txt.txt",'r')

# %%
print(f1.read())
# Out:
# hai how are you

# %%
f1.close()

# %%
i=open("image.jpg",'rb')

# %%
g=i.read()

# %%
j=open("img.jpg",'wb')

# %%
j.write(g)
# Out:
# 2273087

# %%
j.close()

# %%
l=open('a.jpg','rb')

# %%
print(l.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x02\xaeExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\n\x01\x0f\x00\x02\x00\x00\x00\n\x00\x00\x00\x86\x01\x10\x00\x02\x00\x00\x00\x06\x00\x00\x00\x90\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\x96\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\x9e\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x08\x00\x00\x00\xa6\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xae\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xc2\x88%\x00\x04\x00\x00\x00\x01\x00\x00\x024\x00\x00\x00\x00Panasonic\x00DC-G9\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Ver.0.4\x002017:12:03 14:19:50\x00\x00\x19\x82\x9a\x00\x05\x00\x00\x00\x01\x00\x00\x01\xf4\x88"\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x88\'\x00\x03\x00\x00\x00\x01\x03\xe8\x00\x00\x90\x00\x00\x07\x00\x00\x00\x040231\x90\x03\x00\x02\x00\x00\x00\x14\x00\x00\x01\xfc\x90\x04\x00\x02\x00\x00\x00\x14\x00\x00\x02\x10\x
# ...

# %%
t=l.read()

# %%
e=open('exced.jpg','ab')

# %%
e.write(t)
e.close()

# %%
hi=open('a.jpg','rb')
l=hi.read()
print(l)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x02\xaeExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\n\x01\x0f\x00\x02\x00\x00\x00\n\x00\x00\x00\x86\x01\x10\x00\x02\x00\x00\x00\x06\x00\x00\x00\x90\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\x96\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\x9e\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\x08\x00\x00\x00\xa6\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xae\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xc2\x88%\x00\x04\x00\x00\x00\x01\x00\x00\x024\x00\x00\x00\x00Panasonic\x00DC-G9\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Ver.0.4\x002017:12:03 14:19:50\x00\x00\x19\x82\x9a\x00\x05\x00\x00\x00\x01\x00\x00\x01\xf4\x88"\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x88\'\x00\x03\x00\x00\x00\x01\x03\xe8\x00\x00\x90\x00\x00\x07\x00\x00\x00\x040231\x90\x03\x00\x02\x00\x00\x00\x14\x00\x00\x01\xfc\x90\x04\x00\x02\x00\x00\x00\x14\x00\x00\x02\x10\x
# ...

# %%
hello=open('grd.jpg','ab')
hello.write(l)
# Out:
# 77238

# %%
di=open('t.txt','w')
di.write("hvccbdcfqefevedvcq")
di.close()

# %%
fi=open('t.txt','a')
fi.write('\n')
fi.write("123457678889")
#fi.write('\n')
fi.close()

# %%
def even(n):
    if (n%2==0):
        return True
    return False
n=int(input())
e=open('t.txt','a') 
for i in range(0,n):
    if even(i):
        #e=open('t.txt','a') 
        e.write('\n')
        e.write(str(i))
e.close()
# Out:
# 10000

# %%
e=open('t.txt','a') 
e.write('\n')
e.write(str(i))
e.close()

# %%
n=int(input())
s=str(n)
l=[]
for i in range(0,len(s)):
    l.append(int(s[i]))
a=set(l)
print(a)
if len(a)==10:
    print(True)
else:
    print(False)
# Out:
# 12335576545678876543
# {1, 2, 3, 4, 5, 6, 7, 8}
# False

# %%
with open('txt.txt','r')as f:
    print(f.read())
# Out:
# hai how are you

# %%
with open('txt.txt','a')as f:
    while(True):
        s=input()
        if(s=="Exit"):
            break
        else:
            f.write('\n'+s)
# Out:
# hi ra e tokkalo matter ento ardam kavtledu
# hmm
# jsnc
# Exit

# %%
with open('txt.txt','r')as f:
    print(f.read())
# Out:
# hai how are youhai ra how are how well you doing
# hi bro whats up
# hi ra e tokkalo matter ento ardam kavtledu
# hmm
# jsnc
